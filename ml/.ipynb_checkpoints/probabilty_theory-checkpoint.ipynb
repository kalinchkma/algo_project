# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = np.linspace(-1, 1, 100)
y = np.linspace(-1, 1, 100)

# %%
x = np.sin(2*np.pi*x)
y = np.cos(2*np.pi*x)

# %%
x, y
# Out:
# (array([ 2.44929360e-16,  1.26592454e-01,  2.51147987e-01,  3.71662456e-01,
#          4.86196736e-01,  5.92907929e-01,  6.90079011e-01,  7.76146464e-01,
#          8.49725430e-01,  9.09631995e-01,  9.54902241e-01,  9.84807753e-01,
#          9.98867339e-01,  9.96854776e-01,  9.78802446e-01,  9.45000819e-01,
#          8.95993774e-01,  8.32569855e-01,  7.55749574e-01,  6.66769001e-01,
#          5.67059864e-01,  4.58226522e-01,  3.42020143e-01,  2.20310533e-01,
#          9.50560433e-02, -3.17279335e-02, -1.58001396e-01, -2.81732557e-01,
#         -4.00930535e-01, -5.13677392e-01, -6.18158986e-01, -7.12694171e-01,
#         -7.95761841e-01, -8.66025404e-01, -9.22354294e-01, -9.63842159e-01,
#         -9.89821442e-01, -9.99874128e-01, -9.93838464e-01, -9.71811568e-01,
#         -9.34147860e-01, -8.81453363e-01, -8.14575952e-01, -7.34591709e-01,
#         -6.42787610e-01, -5.40640817e-01, -4.29794912e-01, -3.12033446e-01,
# ...

# %%
plt.scatter(x, y)

# %% [markdown]
# # Polynomial Curve Fitting
#
# ### Data
#
# - X label data x = 1 ..... N [N = 10]
# - Y label data y = sin(2 * pi * x)
# -

# %%
n = 100
x = np.linspace(0, 1, n)
y = np.sin(2*np.pi*x)

# adding noise to y data
mean = 0 # mean of gaussian noise
std_dev = 0.1
noise = np.random.normal(mean, std_dev, y.shape)

pred_y = y + noise


x, y
# Out:
# (array([0.        , 0.01010101, 0.02020202, 0.03030303, 0.04040404,
#         0.05050505, 0.06060606, 0.07070707, 0.08080808, 0.09090909,
#         0.1010101 , 0.11111111, 0.12121212, 0.13131313, 0.14141414,
#         0.15151515, 0.16161616, 0.17171717, 0.18181818, 0.19191919,
#         0.2020202 , 0.21212121, 0.22222222, 0.23232323, 0.24242424,
#         0.25252525, 0.26262626, 0.27272727, 0.28282828, 0.29292929,
#         0.3030303 , 0.31313131, 0.32323232, 0.33333333, 0.34343434,
#         0.35353535, 0.36363636, 0.37373737, 0.38383838, 0.39393939,
#         0.4040404 , 0.41414141, 0.42424242, 0.43434343, 0.44444444,
#         0.45454545, 0.46464646, 0.47474747, 0.48484848, 0.49494949,
#         0.50505051, 0.51515152, 0.52525253, 0.53535354, 0.54545455,
#         0.55555556, 0.56565657, 0.57575758, 0.58585859, 0.5959596 ,
#         0.60606061, 0.61616162, 0.62626263, 0.63636364, 0.64646465,
#         0.65656566, 0.66666667, 0.67676768, 0.68686869, 0.6969697 ,
# ...

# %%
plt.plot(x, y, color="green")
plt.scatter(x, pred_y,)
plt.xlabel("Actual values")
plt.ylabel("sin values")
plt.title("sin wave scatter graph")

plt.show()

# %%
number_list = np.array([23, 32, 6, 87, 12, 90, 1])
print(number_list)
print(np.sort(number_list))
print(np.mean(number_list), np.median(number_list))
# Out:
# [23 32  6 87 12 90  1]
# [ 1  6 12 23 32 87 90]
# 35.857142857142854 23.0

# %%
(23+32)/2
# Out:
# 27.5

# %% [markdown]
# ## Linear Algebra
#
# 1. **Scalars**: A scalar is just a single number, in contrast to most of the other objects studied in linear algebra, which are usually arrays of multiple numbers. Scalars are usually identified as lower-case variable names. Ex: s ∈(element of) R is the slope of the line
# 2. **Vectors**: A vector is an array of numbers. The numbers are arranged in order
